# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemma-4-31b-it"
)

response = llm.invoke("How many moons does Jupiter have?")

print(response.content)
# Out:
# [{'type': 'thinking', 'thinking': '*   Question: "How many moons does Jupiter have?"\n    *   Subject: Jupiter\'s moons.\n\n    *   Jupiter is known for having a very large number of moons.\n    *   The number changes as new, smaller moons are discovered by astronomers.\n    *   *Self-Correction/Verification:* As of the most recent updates (late 2023/early 2024), the count is often cited around 95.\n\n    *   NASA\'s official count and the Minor Planet Center (MPC) track these.\n    *   The current widely accepted number is 95.\n\n    *   *Direct answer:* Jupiter has 95 moons.\n    *   *Contextual detail:* Mention that this number can change as new ones are discovered.\n    *   *Key highlights:* Mention the Galilean moons (Io, Europa, Ganymede, Callisto) because they are the most significant.'}, {'type': 'text', 'text': 'Jupiter has **95 officially recognized moons**.\n\nThis number frequently changes as astronomers discover new, smaller moons orbiting the planet. Among these 95, the
# ...

# %%
response = llm.invoke([
        ["system","assign ans in short on line"],
        ["human","How many moons does Jupiter have?"]
])
print(response.text)
# Out:
# Jupiter has 95 moons.

# %%
promt="write a single tagline for a quirky coffee shop. only ouput the tagline noting else."
llm = ChatGoogleGenerativeAI(model="gemini-3.7-flash",temperature=0)
response = llm.invoke(promt)
print(response.text)
# Out:
# Brewed for the beautifully weird.

# %%
promt="write a single tagline for a quirky coffee shop. only ouput the tagline noting else."
llm = ChatGoogleGenerativeAI(model="gemini-3.7-flash",temperature=2)
response = llm.invoke(promt)
print(response.text)
# Out:
# Unusually good coffee for wonderfully weird humans.

# %%
promt="write a single tagline for a quirky coffee shop. only ouput the tagline noting else."
llm = ChatGoogleGenerativeAI(
    model="gemma-4-31b-it",
    temperature=2
)

response = llm.invoke(promt)
print(response.text)
# Out:
# Stay grounded, stay weird.
